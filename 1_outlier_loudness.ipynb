# %% [markdown]
# ### 1. First we found out that music feature are in between (0,1) except Loudness.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Spotify_Dataset_V3.csv' , sep = ';')
df.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
# 3         0.812   0.479   -5678.0        0.333         0.213
# 4         0.812   0.479   -5678.0        0.333         0.213
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# 1             0.000    0.834    Artist 2      Peso Pluma    Nationality 2
# 2             0.629    0.234    Artist 1       Bad Bunny    Nationality 1
# 3             0.000    0.559    Artist 1       Yng Lvcas    Nationality 1
# 4             0.000    0.559    Artist 2      Peso Pluma    Nationality 2
#
#    Nationality      Continent  Points (Total)  \
# 0       Mexico  Latin-America             200
# 1       Mexico  Latin-America             200
# 2  Puerto Rico  Latin-America             199
# 3       Mexico  Latin-America             198
# 4       Mexico  Latin-America             198
#
#    Points (Ind for each Artist/Nat)                      id  \
# 0                             100.0  3qQbCzHBycnDpGskqOWY0E
# 1                             100.0  3qQbCzHBycnDpGskqOWY0E
# 2                             199.0  7ro0hRteUMfnOioTFI5TG1
# 3                              99.0  2UW7JaomAMuX9pZrjVpHAU
# 4                              99.0  2UW7JaomAMuX9pZrjVpHAU
#
#                                             Song URL
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2  https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...

# %%
df['Loudness']
# Out:
# 0         -5176.0
# 1         -5176.0
# 2         -4019.0
# 3         -5678.0
# 4         -5678.0
#            ...
# 651931    -6644.0
# 651932   -10908.0
# 651933    -5779.0
# 651934    -6125.0
# 651935    -6125.0
# Name: Loudness, Length: 651936, dtype: float64

# %%
df['Loudness'].shape
# Out:
# (651936,)

# %% [markdown]
# ### 2. Normally, The loudness could be between -60 and 0 decibel, so we check how many data exceed this interval

# %%
((df['Loudness'] < -60) | (df['Loudness'] > 0)).value_counts()
# Out:
# Loudness
# True     587229
# False     64707
# Name: count, dtype: int64

# %% [markdown]
# ### 3. We decided to seperate data into 2 groups which are not in interval and interval.

# %%
loudness_range = (-60, 0)
non_outlier_loudness_mask = ((df['Loudness'] >= loudness_range[0]) & (df['Loudness'] <= loudness_range[1]))
non_outlier_loudness = df[(df['Loudness'] >=loudness_range[0]) & (df['Loudness'] <= loudness_range[1])]

# %%
print("Before cleaning :",df.shape)
print("After cleaning :",non_outlier_loudness.shape)
# Out:
# Before cleaning : (651936, 20)
# After cleaning : (64707, 20)

# %% [markdown]
# ### 4. We decided to plot histogram to check distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Loudness'], bins=50, kde=True, color='orange')
plt.title('Loudness Distribution')
plt.xlabel('Loudness (dB)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 5. Since our data is in mmdB we need to divide by 10000
# convert Loudness column (mmdB -> dB)

# %%
# 2. Isolate the 'Other Data' (Outliers) using the negation operator (~)
# We use .copy() to create an independent DataFrame, preventing SettingWithCopyWarning.
df_loudness_outliers = df[~non_outlier_loudness_mask].copy()

# 3. Apply the Transformation: Divide *only* the 'Loudness' column by 1000
df_loudness_outliers['Loudness'] = df_loudness_outliers['Loudness'] / 1000

# 4. Combine the Cleaned Data (df_new) and the Scaled Outlier Data (df_outliers)
df_combined = pd.concat([df_loudness_outliers, non_outlier_loudness])
df = df_combined
print("Shape of the combined DataFrame:", df_combined.shape)
print("Transformation completed on 'Loudness' for outlier rows.")
# Out:
# Shape of the combined DataFrame: (651936, 20)
# Transformation completed on 'Loudness' for outlier rows.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Loudness'], bins=50, kde=True, color='orange')
plt.title('Loudness Distribution')
plt.xlabel('Loudness (dB)')
plt.ylabel('Frequency')
plt.show()

# %%
df['Loudness'].describe()
# Out:
# count    651936.000000
# mean         -5.897752
# std           2.304712
# min         -34.475000
# 25%          -7.067000
# 50%          -5.520000
# 75%          -4.325000
# max           1.509000
# Name: Loudness, dtype: float64

# %%
print(df['Loudness'].max(), df['Loudness'].min())
# Out:
# 1.509 -34.475

# %% [markdown]
#  ### 6. Check data that have Loudness > 0 dB

# %%
print("Number of Loudness > 0 :",df[df['Loudness'] > 0].shape[0])
print('All value more than 0 dB',df[df['Loudness'] > 0]['Loudness'].sort_values().unique())
# Out:
# Number of Loudness > 0 : 113
# All value more than 0 dB [1.750e-04 9.630e-04 1.509e+00]

# %%
df[df['Loudness'] > 0].head(10)
# Out:
#        Rank        Title                                           Artists  \
# 28941   179  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 28942   179  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 28943   179  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 28944   179  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 30612   198  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 30613   198  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 30614   198  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 30615   198  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 30910   159  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
# 30911   159  Puta Mexica  DJ Jeeh FDC, MC Menor MT, Yuri Redicopa, Mc Pelé
#
#              Date  Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 28941  18/02/2023         0.853   0.913  0.000963        0.051         0.655
# 28942  18/02/2023         0.853   0.913  0.000963        0.051         0.655
# 28943  18/02/2023         0.853   0.913  0.000963        0.051         0.655
# 28944  18/02/2023         0.853   0.913  0.000963        0.051         0.655
# 30612  12/02/2023         0.853   0.913  0.000963        0.051         0.655
# 30613  12/02/2023         0.853   0.913  0.000963        0.051         0.655
# 30614  12/02/2023         0.853   0.913  0.000963        0.051         0.655
# 30615  12/02/2023         0.853   0.913  0.000963        0.051         0.655
# 30910  11/02/2023         0.853   0.913  0.000963        0.051         0.655
# 30911  11/02/2023         0.853   0.913  0.000963        0.051         0.655
#
#        Instrumentalness  Valence # of Artist  Artist (Ind.) # of Nationality  \
# 28941             0.024    0.952    Artist 1    DJ Jeeh FDC    Nationality 1
# 28942             0.024    0.952    Artist 2    MC Menor MT    Nationality 2
# 28943             0.024    0.952    Artist 3  Yuri Redicopa    Nationality 3
# 28944             0.024    0.952    Artist 4        Mc Pelé    Nationality 4
# 30612             0.024    0.952    Artist 1    DJ Jeeh FDC    Nationality 1
# 30613             0.024    0.952    Artist 2    MC Menor MT    Nationality 2
# 30614             0.024    0.952    Artist 3  Yuri Redicopa    Nationality 3
# 30615             0.024    0.952    Artist 4        Mc Pelé    Nationality 4
# 30910             0.024    0.952    Artist 1    DJ Jeeh FDC    Nationality 1
# 30911             0.024    0.952    Artist 2    MC Menor MT    Nationality 2
#
#       Nationality      Continent  Points (Total)  \
# 28941      Brazil  Latin-America              22
# 28942      Brazil  Latin-America              22
# 28943      Brazil  Latin-America              22
# 28944      Brazil  Latin-America              22
# 30612      Brazil  Latin-America               3
# 30613      Brazil  Latin-America               3
# 30614      Brazil  Latin-America               3
# 30615      Brazil  Latin-America               3
# 30910      Brazil  Latin-America              42
# 30911      Brazil  Latin-America              42
#
#        Points (Ind for each Artist/Nat)                      id  \
# 28941                               6.0  4mD9hjoTckjeL1CrJCx0MT
# 28942                               6.0  4mD9hjoTckjeL1CrJCx0MT
# 28943                               6.0  4mD9hjoTckjeL1CrJCx0MT
# 28944                               6.0  4mD9hjoTckjeL1CrJCx0MT
# 30612                               1.0  4mD9hjoTckjeL1CrJCx0MT
# 30613                               1.0  4mD9hjoTckjeL1CrJCx0MT
# 30614                               1.0  4mD9hjoTckjeL1CrJCx0MT
# 30615                               1.0  4mD9hjoTckjeL1CrJCx0MT
# 30910                              10.0  4mD9hjoTckjeL1CrJCx0MT
# 30911                              10.0  4mD9hjoTckjeL1CrJCx0MT
#
#                                                 Song URL
# 28941  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 28942  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 28943  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 28944  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 30612  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 30613  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 30614  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 30615  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 30910  https://open.spotify.com/track/4mD9hjoTckjeL1C...
# 30911  https://open.spotify.com/track/4mD9hjoTckjeL1C...

# %% [markdown]
# ### 7. Normally Song that has decibel over 0 will be distored so we decided to convert them to 0 to make it sensible

# %%
print("Number of songs have Loudness > 0 : ",df[df['Loudness'] > 0]['Title'].unique().shape[0])
print("Song : ",df[df['Loudness'] > 0]['Title'].unique())
# Out:
# Number of songs have Loudness > 0 :  3
# Song :  ['Puta Mexica' 'Na Raba Toma Tapão'
#  'Welcome to the Party (with French Monta & Lil Pump, feat. Zhavia Ward) - from Deadpool 2']

# %%
df.loc[df['Loudness'] > 0, 'Loudness'] = 0
print("Number of songs have Loudness > 0 : ",df[df['Loudness'] > 0]['Title'].unique().shape[0])
# Out:
# Number of songs have Loudness > 0 :  0

# %%
df['Loudness'].describe()
# Out:
# count    651936.000000
# mean         -5.897808
# std           2.304552
# min         -34.475000
# 25%          -7.067000
# 50%          -5.520000
# 75%          -4.325000
# max           0.000000
# Name: Loudness, dtype: float64

# %%
sns.histplot(df['Loudness'], bins=50, kde=True, color='orange')
plt.title('Distribution of Loudness')
plt.xlabel('Loudness (dB)')
plt.show()

# %%
sns.boxplot(x=df['Loudness'])
# Out:
# <Axes: xlabel='Loudness'>

# %% [markdown]
# ### 8. After we did a boxplot for loudness, we found out it has some outliers. We decided to drop it

# %%
threshold = -25 

total = len(df)

outliers = len(df[df['Loudness'] < threshold])

percentage = (outliers / total) * 100

print(f"Number of songs with Loudness < {threshold} dB: {outliers:,}")
print(f"Percentage of total: {percentage:.2f}%")
# Out:
# Number of songs with Loudness < -25 dB: 11
# Percentage of total: 0.00%

# %%
df
# Out:
#         Rank                           Title                     Artists  \
# 0          1                 Ella Baila Sola  Eslabon Armado, Peso Pluma
# 1          1                 Ella Baila Sola  Eslabon Armado, Peso Pluma
# 2          2                  WHERE SHE GOES                   Bad Bunny
# 3          3                 La Bebe - Remix       Yng Lvcas, Peso Pluma
# 4          3                 La Bebe - Remix       Yng Lvcas, Peso Pluma
# ...      ...                             ...                         ...
# 651848   123                      Photograph                  Ed Sheeran
# 651875   148  Dynamite (feat. Pretty Sister)                       Nause
# 651886   157               Love On The Brain                     Rihanna
# 651887   158  Desde Esa Noche (feat. Maluma)                      Thalia
# 651900   170                      goosebumps                Travis Scott
#
#               Date  Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0       29/05/2023         0.668   0.758    -5.176        0.033         0.483
# 1       29/05/2023         0.668   0.758    -5.176        0.033         0.483
# 2       29/05/2023         0.652   0.800    -4.019        0.061         0.143
# 3       29/05/2023         0.812   0.479    -5.678        0.333         0.213
# 4       29/05/2023         0.812   0.479    -5.678        0.333         0.213
# ...            ...           ...     ...       ...          ...           ...
# 651848  01/01/2017         0.614   0.379   -10.480        0.048         0.607
# 651875  01/01/2017         0.811   0.801    -6.000        0.080         0.055
# 651886  01/01/2017         0.509   0.637    -4.830        0.047         0.072
# 651887  01/01/2017         0.780   0.929    -0.739        0.053         0.171
# 651900  01/01/2017         0.841   0.728    -3.370        0.048         0.085
#
#         Instrumentalness  Valence # of Artist   Artist (Ind.)  \
# 0                  0.000    0.834    Artist 1  Eslabon Armado
# 1                  0.000    0.834    Artist 2      Peso Pluma
# 2                  0.629    0.234    Artist 1       Bad Bunny
# 3                  0.000    0.559    Artist 1       Yng Lvcas
# 4                  0.000    0.559    Artist 2      Peso Pluma
# ...                  ...      ...         ...             ...
# 651848             0.000    0.201    Artist 1      Ed Sheeran
# 651875             0.000    0.693    Artist 1           Nause
# 651886             0.000    0.378    Artist 1         Rihanna
# 651887             0.000    0.837    Artist 1          Thalia
# 651900             0.000    0.430    Artist 1    Travis Scott
#
#        # of Nationality     Nationality      Continent  Points (Total)  \
# 0         Nationality 1          Mexico  Latin-America             200
# 1         Nationality 2          Mexico  Latin-America             200
# 2         Nationality 1     Puerto Rico  Latin-America             199
# 3         Nationality 1          Mexico  Latin-America             198
# 4         Nationality 2          Mexico  Latin-America             198
# ...                 ...             ...            ...             ...
# 651848    Nationality 1  United Kingdom         Europe              78
# 651875    Nationality 1          Sweden         Europe              53
# 651886    Nationality 1        Barbados  Anglo-America              44
# 651887    Nationality 1          Mexico  Latin-America              43
# 651900    Nationality 1   United States  Anglo-America              31
#
#         Points (Ind for each Artist/Nat)                      id  \
# 0                                  100.0  3qQbCzHBycnDpGskqOWY0E
# 1                                  100.0  3qQbCzHBycnDpGskqOWY0E
# 2                                  199.0  7ro0hRteUMfnOioTFI5TG1
# 3                                   99.0  2UW7JaomAMuX9pZrjVpHAU
# 4                                   99.0  2UW7JaomAMuX9pZrjVpHAU
# ...                                  ...                     ...
# 651848                              78.0  6fxVffaTuwjgEk5h9QyRjy
# 651875                              53.0  2Ae5awwKvQpTBKQHr1TYCg
# 651886                              44.0  2aksifNn5ph8igDOkPBA02
# 651887                              43.0  1pWYnQIlqxTh5bxuPmTG4E
# 651900                              31.0  6gBFPUFcJLzWGx4lenP6h2
#
#                                                  Song URL
# 0       https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1       https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2       https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3       https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 4       https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# ...                                                   ...
# 651848  https://open.spotify.com/track/6fxVffaTuwjgEk5...
# 651875  https://open.spotify.com/track/2Ae5awwKvQpTBKQ...
# 651886  https://open.spotify.com/track/2aksifNn5ph8igD...
# 651887  https://open.spotify.com/track/1pWYnQIlqxTh5bx...
# 651900  https://open.spotify.com/track/6gBFPUFcJLzWGx4...
#
# [651936 rows x 20 columns]

# %%
df.to_csv('outlier_loudness.csv', index=False, sep =';')
