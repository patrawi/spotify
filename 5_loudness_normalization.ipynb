# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('change_date_time_column.csv' , sep = ';')
df.head()
# Out:
#    Rank              Title                     Artists        Date  \
# 0     1    Ella Baila Sola  Eslabon Armado, Peso Pluma  2023-05-29
# 1     2     WHERE SHE GOES                   Bad Bunny  2023-05-29
# 2     3    La Bebe - Remix       Yng Lvcas, Peso Pluma  2023-05-29
# 3     4  Cupid - Twin Ver.                 FIFTY FIFTY  2023-05-29
# 4     5          un x100to   Grupo Frontera, Bad Bunny  2023-05-29
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758    -5.176        0.033         0.483
# 1         0.652   0.800    -4.019        0.061         0.143
# 2         0.812   0.479    -5.678        0.333         0.213
# 3         0.783   0.592    -8.332        0.033         0.435
# 4         0.569   0.724    -4.076        0.047         0.228
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# ...

# %% [markdown]
# ## Normalize
# - Loudness Column

# %%
df['Loudness'].describe()
# Out:
# count    467061.000000
# mean         -6.108040
# std           2.363197
# min         -34.475000
# 25%          -7.274000
# 50%          -5.716000
# 75%          -4.469000
# max           0.000000
# Name: Loudness, dtype: float64

# %%
scaler = MinMaxScaler()
df['Loudness_norm'] = scaler.fit_transform(df[['Loudness']])

# %%
df['Loudness_norm'].describe()
# Out:
# count    467061.000000
# mean          0.822827
# std           0.068548
# min           0.000000
# 25%           0.789007
# 50%           0.834199
# 75%           0.870370
# max           1.000000
# Name: Loudness_norm, dtype: float64

# %%
df.head()
# Out:
#    Rank              Title                     Artists        Date  \
# 0     1    Ella Baila Sola  Eslabon Armado, Peso Pluma  2023-05-29
# 1     2     WHERE SHE GOES                   Bad Bunny  2023-05-29
# 2     3    La Bebe - Remix       Yng Lvcas, Peso Pluma  2023-05-29
# 3     4  Cupid - Twin Ver.                 FIFTY FIFTY  2023-05-29
# 4     5          un x100to   Grupo Frontera, Bad Bunny  2023-05-29
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758    -5.176        0.033         0.483
# 1         0.652   0.800    -4.019        0.061         0.143
# 2         0.812   0.479    -5.678        0.333         0.213
# 3         0.783   0.592    -8.332        0.033         0.435
# 4         0.569   0.724    -4.076        0.047         0.228
#
#    Instrumentalness  ...  # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000  ...     Artist 1  Eslabon Armado    Nationality 1
# ...

# %%
df.to_csv('final_cleaned_data.csv', sep = ';', index = False)
