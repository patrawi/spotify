# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Spotify_Dataset_V3 2.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('Spotify_Dataset_V3 2.csv', delimiter=';')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#         Rank                          Title                     Artists  \
# 0          1                Ella Baila Sola  Eslabon Armado, Peso Pluma
# 1          1                Ella Baila Sola  Eslabon Armado, Peso Pluma
# 2          2                 WHERE SHE GOES                   Bad Bunny
# 3          3                La Bebe - Remix       Yng Lvcas, Peso Pluma
# 4          3                La Bebe - Remix       Yng Lvcas, Peso Pluma
# ...      ...                            ...                         ...
# 651931   197                        Oh Lord                   MiC LOWRY
# 651932   198  Superstition - Single Version               Stevie Wonder
# 651933   199                        Secrets                  The Weeknd
# 651934   200                Ni**as In Paris           JAY-Z, Kanye West
# 651935   200                Ni**as In Paris           JAY-Z, Kanye West
#
#               Date  Danceability  Energy  Loudness  Speechiness  Acousticness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651936 entries, 0 to 651935
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Rank                              651936 non-null  int64
#  1   Title                             651936 non-null  object
#  2   Artists                           651936 non-null  object
#  3   Date                              651936 non-null  object
#  4   Danceability                      651936 non-null  float64
#  5   Energy                            651936 non-null  float64
#  6   Loudness                          651936 non-null  float64
#  7   Speechiness                       651936 non-null  float64
#  8   Acousticness                      651936 non-null  float64
#  9   Instrumentalness                  651936 non-null  float64
#  10  Valence                           651936 non-null  float64
# ...

# %%
df[['Continent']].nunique()
# Out:
# Continent    7
# dtype: int64

# %%
df[['Title']].nunique()
# Out:
# Title    7457
# dtype: int64

# %%
print(f"The number of artist: {df[['Artists']].nunique()}")
# Out:
# The number of artist: Artists    2928
# dtype: int64

# %%
df[['Danceability']].describe()
# Out:
#         Danceability
# count  651936.000000
# mean        0.697730
# std         0.133186
# min         0.073000
# 25%         0.617000
# 50%         0.719000
# 75%         0.793000
# max         0.985000

# %%
df[(df['Loudness'] > -60) & (df['Loudness'] < 0)]
# Out:
#         Rank                                              Title  \
# 14        11                                         Classy 101
# 15        11                                         Classy 101
# 25        17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 26        17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 27        17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# ...      ...                                                ...
# 651848   123                                         Photograph
# 651875   148                     Dynamite (feat. Pretty Sister)
# 651886   157                                  Love On The Brain
# 651887   158                     Desde Esa Noche (feat. Maluma)
# 651900   170                                         goosebumps
#
#                                                 Artists       Date  \
# 14                                     Feid, Young Miko 2023-05-29
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651936 entries, 0 to 651935
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Rank                              651936 non-null  int64
#  1   Title                             651936 non-null  object
#  2   Artists                           651936 non-null  object
#  3   Date                              651936 non-null  datetime64[ns]
#  4   Danceability                      651936 non-null  float64
#  5   Energy                            651936 non-null  float64
#  6   Loudness                          651936 non-null  float64
#  7   Speechiness                       651936 non-null  float64
#  8   Acousticness                      651936 non-null  float64
#  9   Instrumentalness                  651936 non-null  float64
#  10  Valence                           651936 non-null  float64
# ...

# %%
df[df['# of Artist'] == 'Artist 9']['Title']
# Out:
# 265937    Bande organisée
# 266202    Bande organisée
# 266473    Bande organisée
# 266739    Bande organisée
# 267006    Bande organisée
#                ...
# 375796             Quizás
# 376100             Quizás
# 376405             Quizás
# 376718             Quizás
# 377028             Quizás
# Name: Title, Length: 90, dtype: object

# %%
df['# of Nationality'].unique()
# Out:
# array(['Nationality 1', 'Nationality 2', 'Nationality 3', 'Nationality 4',
#        'Nationality 5', 'Nationality 6', 'Nationality 7', 'Nationality 8',
#        'Nationality 9'], dtype=object)

# %%
df[df['Title'] == 'Bande organisée']
# Out:
#         Rank            Title  \
# 265929   200  Bande organisée
# 265930   200  Bande organisée
# 265931   200  Bande organisée
# 265932   200  Bande organisée
# 265933   200  Bande organisée
# ...      ...              ...
# 284350   194  Bande organisée
# 284351   194  Bande organisée
# 284352   194  Bande organisée
# 284353   194  Bande organisée
# 284354   194  Bande organisée
#
#                                                   Artists       Date  \
# 265929  13 Organisé, SCH, Kofs, Jul, ps, Soso Maness, ... 2020-10-25
# 265930  13 Organisé, SCH, Kofs, Jul, ps, Soso Maness, ... 2020-10-25
# 265931  13 Organisé, SCH, Kofs, Jul, ps, Soso Maness, ... 2020-10-25
# 265932  13 Organisé, SCH, Kofs, Jul, ps, Soso Maness, ... 2020-10-25
# 265933  13 Organisé, SCH, Kofs, Jul, ps, Soso Maness, ... 2020-10-25
# ...                                                   ...        ...
# 284350  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-08-18
# ...

# %%
df[['Loudness']] = df[['Loudness']]/1000

# %%
df[(df['id'] == '205HNJ73cgpC0LAOnuQiWT') & (df['Date'] == pd.to_datetime('2020-10-08'))]
# Out:
#         Rank            Title  \
# 270469   168  Bande organisée
# 270470   168  Bande organisée
# 270471   168  Bande organisée
# 270472   168  Bande organisée
# 270473   168  Bande organisée
# 270474   168  Bande organisée
# 270475   168  Bande organisée
# 270476   168  Bande organisée
# 270477   168  Bande organisée
#
#                                                   Artists       Date  \
# 270469  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270470  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270471  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270472  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270473  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270474  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270475  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270476  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# ...

# %%
df[df['id'] == '205HNJ73cgpC0LAOnuQiWT']
# Out:
#         Rank            Title  \
# 270469   168  Bande organisée
# 270470   168  Bande organisée
# 270471   168  Bande organisée
# 270472   168  Bande organisée
# 270473   168  Bande organisée
# ...      ...              ...
# 284350   194  Bande organisée
# 284351   194  Bande organisée
# 284352   194  Bande organisée
# 284353   194  Bande organisée
# 284354   194  Bande organisée
#
#                                                   Artists       Date  \
# 270469  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270470  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270471  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270472  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# 270473  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-10-08
# ...                                                   ...        ...
# 284350  Kofs, Soso Maness, Elams, Jul, SCH, ps, Solda,... 2020-08-18
# ...

# %%
df[df['Loudness'] > 1.5]
# Out:
#         Rank               Title Artists       Date  Danceability  Energy  \
# 292457   179  Na Raba Toma Tapão   Niack 2020-07-18         0.962   0.787
# 294043   179  Na Raba Toma Tapão   Niack 2020-07-12         0.962   0.787
# 294313   169  Na Raba Toma Tapão   Niack 2020-07-11         0.962   0.787
# 295908   182  Na Raba Toma Tapão   Niack 2020-07-05         0.962   0.787
# 296180   169  Na Raba Toma Tapão   Niack 2020-07-04         0.962   0.787
# 297832   177  Na Raba Toma Tapão   Niack 2020-06-28         0.962   0.787
# 298107   176  Na Raba Toma Tapão   Niack 2020-06-27         0.962   0.787
# 299738   129  Na Raba Toma Tapão   Niack 2020-06-21         0.962   0.787
# 300005   128  Na Raba Toma Tapão   Niack 2020-06-20         0.962   0.787
# 300276   169  Na Raba Toma Tapão   Niack 2020-06-19         0.962   0.787
# 301627   145  Na Raba Toma Tapão   Niack 2020-06-14         0.962   0.787
# 301895   122  Na Raba Toma Tapão   Niack 2020-06-13         0.962   0.787
# ...

# %%
df[['Loudness']].describe()
# Out:
#             Loudness
# count  651936.000000
# mean       -5.295645
# std         2.785261
# min       -34.475000
# 25%        -6.825000
# 50%        -5.206000
# 75%        -3.885000
# max         1.509000

# %%
df['Continent'] =df['Continent'].astype('category')

# %%
for e in df['Continent'].unique():
    print(e)
# Out:
# Latin-America
# Asia
# Anglo-America
# Europe
# Africa
# Oceania
# Unknown

# %%
test_data = df[df['id'] == '205HNJ73cgpC0LAOnuQiWT'][['Rank', 'Date']]

# %%
test_data['Date'].unique()
# Out:
# <DatetimeArray>
# ['2020-10-08 00:00:00', '2020-10-07 00:00:00', '2020-10-06 00:00:00',
#  '2020-10-05 00:00:00', '2020-10-04 00:00:00', '2020-10-03 00:00:00',
#  '2020-10-02 00:00:00', '2020-10-01 00:00:00', '2020-09-30 00:00:00',
#  '2020-09-29 00:00:00', '2020-09-28 00:00:00', '2020-09-27 00:00:00',
#  '2020-09-26 00:00:00', '2020-09-25 00:00:00', '2020-09-24 00:00:00',
#  '2020-09-23 00:00:00', '2020-09-22 00:00:00', '2020-09-21 00:00:00',
#  '2020-09-20 00:00:00', '2020-09-19 00:00:00', '2020-09-18 00:00:00',
#  '2020-09-17 00:00:00', '2020-09-16 00:00:00', '2020-09-15 00:00:00',
#  '2020-09-14 00:00:00', '2020-09-13 00:00:00', '2020-09-12 00:00:00',
#  '2020-09-11 00:00:00', '2020-09-10 00:00:00', '2020-09-09 00:00:00',
#  '2020-09-08 00:00:00', '2020-09-07 00:00:00', '2020-09-06 00:00:00',
#  '2020-09-05 00:00:00', '2020-09-04 00:00:00', '2020-09-03 00:00:00',
#  '2020-09-02 00:00:00', '2020-09-01 00:00:00', '2020-08-31 00:00:00',
# ...

# %%
plt.figure(figsize=(10, 6)) # Sets the size of the plot figure
plt.plot(test_data['Date'], test_data['Rank'])

# 3. Customize the plot for clarity
plt.title('Sample Time Series Analysis')
plt.xlabel('Date')
plt.ylabel('Rank')
plt.grid(True) # Adds a grid to make reading values easier
plt.gcf().autofmt_xdate() # Automatically rotates and aligns date labels to prevent overlap

# 4. Display the plot
plt.show()
