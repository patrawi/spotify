# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('outlier_loudness.csv' , sep = ';')
df.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758    -5.176        0.033         0.483
# 1         0.668   0.758    -5.176        0.033         0.483
# 2         0.652   0.800    -4.019        0.061         0.143
# 3         0.812   0.479    -5.678        0.333         0.213
# 4         0.812   0.479    -5.678        0.333         0.213
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# ...

# %%
df.to_csv('outlier_loudness.csv', index=False, sep =';')

# %% [markdown]
# ### Cleaning duplicated row

# %% [markdown]
# #### Check same 'Rank','Title','Date' in each day
# We found out there are several rows that are duplicated , but they are different in how they manage artist for example

# %%
df[(df['Title'] == 'Better Days (NEIKED x Mae Muller x Polo G)') & (df['Date'] == '08/01/2022') & (df['Artist (Ind.)'] == 'Polo G')]
# Out:
#         Rank                                       Title  \
# 129465    87  Better Days (NEIKED x Mae Muller x Polo G)
# 129468    87  Better Days (NEIKED x Mae Muller x Polo G)
#
#                            Artists        Date  Danceability  Energy  \
# 129465                      NEIKED  08/01/2022         0.717   0.671
# 129468  NEIKED, Mae Muller, Polo G  08/01/2022         0.717   0.671
#
#         Loudness  Speechiness  Acousticness  Instrumentalness  Valence  \
# 129465    -5.077        0.034         0.002               0.0    0.699
# 129468    -5.077        0.034         0.002               0.0    0.699
#
#        # of Artist Artist (Ind.) # of Nationality    Nationality  \
# 129465    Artist 3        Polo G    Nationality 3  United States
# 129468    Artist 3        Polo G    Nationality 3  United States
#
#             Continent  Points (Total)  Points (Ind for each Artist/Nat)  \
# 129465  Anglo-America             114                              38.0
# ...

# %%
df_dup = df.duplicated(subset=['Rank','Title','Date'] , keep = False)
df[df_dup][['Rank','Title','Date']].value_counts()
# Out:
# Rank  Title            Date
# 87    Quizás           24/09/2019    9
# 86    Quizás           25/09/2019    9
# 97    Bande organisée  05/09/2020    9
# 136   Bande organisée  28/09/2020    9
# 117   Bande organisée  30/09/2020    9
#                                     ..
# 72    Robarte un Beso  26/11/2017    2
#                        23/11/2017    2
#                        20/09/2017    2
#                        18/10/2017    2
# 200   Échame La Culpa  22/08/2018    2
# Name: count, Length: 127129, dtype: int64

# %%
df_dup = df.duplicated(subset=['Rank','Title','Date'] , keep = False)
df[df_dup][['Rank','Title','Date','id']]
# Out:
#         Rank             Title        Date                      id
# 0          1   Ella Baila Sola  29/05/2023  3qQbCzHBycnDpGskqOWY0E
# 1          1   Ella Baila Sola  29/05/2023  3qQbCzHBycnDpGskqOWY0E
# 3          3   La Bebe - Remix  29/05/2023  2UW7JaomAMuX9pZrjVpHAU
# 4          3   La Bebe - Remix  29/05/2023  2UW7JaomAMuX9pZrjVpHAU
# 6          5         un x100to  29/05/2023  6pD0ufEQq0xdHSsRbg9LBK
# ...      ...               ...         ...                     ...
# 651918    24          Starving  01/01/2017  1qOLh0tI7trd1zdDKxYZTe
# 651919    24          Starving  01/01/2017  1qOLh0tI7trd1zdDKxYZTe
# 651920    24          Starving  01/01/2017  1qOLh0tI7trd1zdDKxYZTe
# 651924    72  X (feat. Future)  01/01/2017  6fwdbPMwP1zVStm8FybmkO
# 651925    72  X (feat. Future)  01/01/2017  6fwdbPMwP1zVStm8FybmkO
#
# [310310 rows x 4 columns]

# %%
df_new = df.copy()
df_new1 = df_new[['Rank','Title','Artists','Date','Danceability','Energy','Loudness','Speechiness','Acousticness','Instrumentalness','Valence','id']]
df_new1.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758    -5.176        0.033         0.483
# 1         0.668   0.758    -5.176        0.033         0.483
# 2         0.652   0.800    -4.019        0.061         0.143
# 3         0.812   0.479    -5.678        0.333         0.213
# 4         0.812   0.479    -5.678        0.333         0.213
#
#    Instrumentalness  Valence                      id
# 0             0.000    0.834  3qQbCzHBycnDpGskqOWY0E
# 1             0.000    0.834  3qQbCzHBycnDpGskqOWY0E
# ...

# %%
df_dup = df_new.duplicated(subset=['Rank','Title','Date'] , keep = False)
df[df_dup][['Rank','Title','Date','id']]
# Out:
#         Rank             Title        Date                      id
# 0          1   Ella Baila Sola  29/05/2023  3qQbCzHBycnDpGskqOWY0E
# 1          1   Ella Baila Sola  29/05/2023  3qQbCzHBycnDpGskqOWY0E
# 3          3   La Bebe - Remix  29/05/2023  2UW7JaomAMuX9pZrjVpHAU
# 4          3   La Bebe - Remix  29/05/2023  2UW7JaomAMuX9pZrjVpHAU
# 6          5         un x100to  29/05/2023  6pD0ufEQq0xdHSsRbg9LBK
# ...      ...               ...         ...                     ...
# 651918    24          Starving  01/01/2017  1qOLh0tI7trd1zdDKxYZTe
# 651919    24          Starving  01/01/2017  1qOLh0tI7trd1zdDKxYZTe
# 651920    24          Starving  01/01/2017  1qOLh0tI7trd1zdDKxYZTe
# 651924    72  X (feat. Future)  01/01/2017  6fwdbPMwP1zVStm8FybmkO
# 651925    72  X (feat. Future)  01/01/2017  6fwdbPMwP1zVStm8FybmkO
#
# [310310 rows x 4 columns]

# %%
df_clean = df_new.drop_duplicates(subset=['Rank', 'Title', 'Date'], keep='first').copy()
print("Before delete duplicated row: ", df.shape[0])
print("After delete duplicated row: ", df_clean.shape[0])
# Out:
# Before delete duplicated row:  651936
# After delete duplicated row:  468755

# %% [markdown]
# - Check same Rank in each day

# %%
df_clean[df_clean.duplicated(subset=['Rank','id','Date'] , keep = False)]
# Out:
#         Rank                                      Title  \
# 7905     199                              Lose Yourself
# 7906     199   Lose Yourself - From "8 Mile" Soundtrack
# 8160     191                              Lose Yourself
# 8161     191   Lose Yourself - From "8 Mile" Soundtrack
# 8413     187                              Lose Yourself
# ...      ...                                        ...
# 586725    47  This Is What You Came For (feat. Rihanna)
# 586961    46                  This Is What You Came For
# 586962    46  This Is What You Came For (feat. Rihanna)
# 587036    34                  This Is What You Came For
# 587037    34  This Is What You Came For (feat. Rihanna)
#
#                       Artists        Date  Danceability  Energy  Loudness  \
# 7905                   Eminem  28/04/2023         0.686   0.735    -4.616
# 7906                   Eminem  28/04/2023         0.686   0.735    -4.616
# ...

# %%
df_clean[df_clean.duplicated(subset=['Rank','Date'], keep=False)]
# Out:
#         Rank                                      Title  \
# 7905     199                              Lose Yourself
# 7906     199   Lose Yourself - From "8 Mile" Soundtrack
# 8160     191                              Lose Yourself
# 8161     191   Lose Yourself - From "8 Mile" Soundtrack
# 8413     187                              Lose Yourself
# ...      ...                                        ...
# 586725    47  This Is What You Came For (feat. Rihanna)
# 586961    46                  This Is What You Came For
# 586962    46  This Is What You Came For (feat. Rihanna)
# 587036    34                  This Is What You Came For
# 587037    34  This Is What You Came For (feat. Rihanna)
#
#                       Artists        Date  Danceability  Energy  Loudness  \
# 7905                   Eminem  28/04/2023         0.686   0.735    -4.616
# 7906                   Eminem  28/04/2023         0.686   0.735    -4.616
# ...

# %%
print(df_clean[df_clean.duplicated(subset=['Rank','Date'], keep=False)][['Rank','Date']].value_counts())
print("Number of ducplicated row :",df_clean[df_clean.duplicated(subset=['Rank','Date'], keep=False)][['Rank','Date']].shape[0])
# Out:
# Rank  Date
# 17    25/06/2021    2
# 166   20/08/2022    2
# 167   26/01/2023    2
#       24/02/2022    2
#       23/11/2021    2
#                    ..
# 125   10/04/2022    2
#       01/05/2022    2
# 124   19/03/2022    2
#       18/03/2022    2
# 200   27/07/2022    2
# Name: count, Length: 1685, dtype: int64
# Number of ducplicated row : 3370

# %%
df_clean[df_clean.duplicated(subset=['Rank','Date'], keep=False)][['Rank','Title','Date','id']]
# Out:
#         Rank                                      Title        Date  \
# 7905     199                              Lose Yourself  28/04/2023
# 7906     199   Lose Yourself - From "8 Mile" Soundtrack  28/04/2023
# 8160     191                              Lose Yourself  27/04/2023
# 8161     191   Lose Yourself - From "8 Mile" Soundtrack  27/04/2023
# 8413     187                              Lose Yourself  26/04/2023
# ...      ...                                        ...         ...
# 586725    47  This Is What You Came For (feat. Rihanna)  03/01/2017
# 586961    46                  This Is What You Came For  02/01/2017
# 586962    46  This Is What You Came For (feat. Rihanna)  02/01/2017
# 587036    34                  This Is What You Came For  01/01/2017
# 587037    34  This Is What You Came For (feat. Rihanna)  01/01/2017
#
#                             id
# 7905    1v7L65Lzy0j0vdpRjJewt1
# 7906    1v7L65Lzy0j0vdpRjJewt1
# 8160    1v7L65Lzy0j0vdpRjJewt1
# ...

# %%
df_clean_same_rank_in_each_date = df_clean.drop_duplicates(subset=['Rank','Date'], keep='first').copy()
print("Before delete duplicated row: ", df.shape[0])
print("After delete duplicated row(Title,Date,Rank): ", df_clean.shape[0])
print("After delete duplicated row (Date,Rank) :", df_clean_same_rank_in_each_date.shape[0])
# Out:
# Before delete duplicated row:  651936
# After delete duplicated row(Title,Date,Rank):  468755
# After delete duplicated row (Date,Rank) : 467070

# %% [markdown]
# - Check different rank in the same date

# %%
df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['id','Date'], keep=False)]
print(df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['id','Date'], keep=False)].shape[0])
print(df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['Title','Date'], keep=False)].shape[0])
# Out:
# 18
# 2640

# %%
print(df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['id','Date','Title'], keep=False)].shape)
df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['id','Date','Title'], keep=False)]
# Out:
# (18, 20)
#        Rank               Title                    Artists        Date  \
# 23936     3  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  21/02/2023
# 23938   196  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  21/02/2023
# 26051     5  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  12/02/2023
# 26053   173  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  12/02/2023
# 26299     7  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  11/02/2023
# 26301   182  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  11/02/2023
# 26540     7  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  10/02/2023
# 26542   163  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  10/02/2023
# 26778    12  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  09/02/2023
# 26780   108  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  09/02/2023
# 27024    18  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  08/02/2023
# 27026   101  Boy's a liar Pt. 2  PinkPantheress, Ice Spice  08/02/2023
# ...

# %%
print(df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['id','Date',], keep=False)].shape)
df_clean_same_rank_in_each_date[df_clean_same_rank_in_each_date.duplicated(subset=['id','Date',], keep=False)][['id','Date','Rank']].value_counts()
# Out:
# (18, 20)
# id                      Date        Rank
# 6AQbmUe0Qwf5PZnt4HmTXv  05/02/2023  115     1
#                                     117     1
#                         21/02/2023  3       1
#                         12/02/2023  173     1
#                                     5       1
#                         11/02/2023  182     1
#                                     7       1
#                         10/02/2023  163     1
#                                     7       1
#                         09/02/2023  108     1
#                                     12      1
#                         08/02/2023  101     1
#                                     18      1
#                         07/02/2023  98      1
#                                     29      1
#                         06/02/2023  112     1
#                                     62      1
#                         21/02/2023  196     1
# Name: count, dtype: int64

# %% [markdown]
# - We decided to keep last

# %%
df_clean_final = df_clean_same_rank_in_each_date.drop_duplicates(subset=['id','Date'], keep='last').copy()
print(df_clean_final.shape[0])
# Out:
# 467061

# %% [markdown]
# - We also find out that there are many songs that have different id but it show the same title, we analyze and found out there are from different location (album , single). So, we decided to keep it

# %%
df_clean_final[df_clean_final.duplicated(subset=['Title','Date','Artists'], keep=False)]
# Out:
#         Rank                                    Title        Artists  \
# 11370     21                                 Chemical    Post Malone
# 11371    173                                 Chemical    Post Malone
# 38392      2        Rockin' Around The Christmas Tree     Brenda Lee
# 38393    156        Rockin' Around The Christmas Tree     Brenda Lee
# 38631      3        Rockin' Around The Christmas Tree     Brenda Lee
# 38632    108        Rockin' Around The Christmas Tree     Brenda Lee
# 128211   188                           Take My Breath     The Weeknd
# 128212    51                           Take My Breath     The Weeknd
# 128504   180                           Take My Breath     The Weeknd
# 128505    38                           Take My Breath     The Weeknd
# 128799   171                           Take My Breath     The Weeknd
# 128800    28                           Take My Breath     The Weeknd
# 129095   160                           Take My Breath     The Weeknd
# ...

# %% [markdown]
# - We also check about song that are different but have the same value in music variables. However, we decided to keep all of them because they are different.

# %%
df_clean_final[df_clean_final.duplicated(subset=['Date','Danceability','Energy','Loudness','Speechiness','Acousticness','Instrumentalness','Valence'], keep=False)]
# Out:
#         Rank                      Title  \
# 18356    145                Peso a Peso
# 18392     64  Si La Calle Llama - Remix
# 456474    79              4th Dimension
# 456520    88               Cudi Montage
#
#                                                 Artists        Date  \
# 18356   Eladio Carrion, Quavo, Rich The Kid, Ñengo Flow  17/03/2023
# 18392                       Eladio Carrion, Myke Towers  17/03/2023
# 456474                     KIDS SEE GHOSTS, Louis Prima  08/06/2018
# 456520                                  KIDS SEE GHOSTS  08/06/2018
#
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 18356          0.469   0.639    -5.381         0.32         0.564
# 18392          0.469   0.639    -5.381         0.32         0.564
# 456474         0.765   0.542    -6.755         0.39         0.278
# 456520         0.765   0.542    -6.755         0.39         0.278
#
#         Instrumentalness  Valence # of Artist    Artist (Ind.)  \
# ...

# %%
print(df.shape[0])
print(df_clean_final.shape[0])
# Out:
# 651936
# 467061

# %%
df_clean_final.to_csv('delete_duplication.csv', index=False, sep =';')
